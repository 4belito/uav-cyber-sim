# %% [markdown]
# ## Simple Mission
#
# This notebook serves to check the ardupilot installation

# %%
import os
import subprocess
import sys
from pathlib import Path
from typing import cast

import pymavlink.dialects.v20.ardupilotmega as mavlink

root = Path.cwd().resolve().parents[1]
sys.path.append(str(root))  

from ardupilot.enums import BRDType, FrameClass, FrameType, MOTPWMType
from config import ARDUPILOT_VEHICLE_PATH, LOGS_PATH, VEH_PARAMS_PATH  # noqa: E402
from helpers import clean  # noqa: E402
from mavlink.customtypes.mission import MissionLoader  # noqa: E402
from mavlink.enums import Autopilot, Cmd, CmdNav, MissionResult, Type  # noqa: E402
from mavlink.util import ask_msg, connect, stop_msg  # noqa: E402
from plan import State  # noqa: E402
from plan.planner import Plan  # noqa: E402

clean()

# %% [markdown]
# #### Launch Copter (ardupilot)

# %%
#This must agrre with first waypoint in mission.waypoint
spawn_str= '-35.3633245,149.1652241,0.0,0' 

sim_vehicle_path = os.path.expanduser(ARDUPILOT_VEHICLE_PATH)
vehicle_cmd = (
    f"python3 {sim_vehicle_path} "
    f"-v ArduCopter "
    f"-I0 --sysid 1 "
    f"--no-rebuild "
    f"--use-dir={LOGS_PATH} "
    f"--add-param-file {VEH_PARAMS_PATH} "
    f"--no-mavproxy "
    f'--custom-location={spawn_str}'
)


# Open a new terminal and run the command
subprocess.Popen(["gnome-terminal","--title=planner","--", 
                  "bash", "-c", f"{vehicle_cmd}; exec bash"])
# Out:
# <Popen: returncode: None args: ['gnome-terminal', '--title=planner', '--', '...>

# %% [markdown]
# #### 1. Connect to the vehicle

# %%
conn = connect("tcp:127.0.0.1:5760")
conn.wait_heartbeat() 
print("✅ Heartbeat received")
# Out:
# [Errno 111] Connection refused sleeping
# ✅ Heartbeat received

# %% [markdown]
# ### 🔍 Identify Vehicle Type and Autopilot Firmware

# %%
msg = conn.recv_match(type='HEARTBEAT', blocking=True)
print(f"Firmware : {Autopilot(msg.autopilot).name}")
print(f"System Type : {Type(msg.type).name }")         # MAV_TYPE
# Out:
# Firmware : ARDUPILOTMEGA
# System Type : QUADROTOR

# %% [markdown]
# ## Parameters

# %%
conn.mav.param_request_list_send(conn.target_system, conn.target_component)

# Receive and store them
params = {}

while True:
    msg = conn.recv_match(type='PARAM_VALUE', blocking=True, timeout=5)
    if msg is None:
        break
    params[msg.param_id] = msg.param_value

print(f"✅ Received {len(params)} parameters")
# Out:
# ✅ Received 1341 parameters

# %%
key="FRAME_CLASS"
print(f"{key}: {FrameClass(params.get(key)).name}")
key="FRAME_TYPE"
print(f"{key}: {FrameType(params.get(key)).name}")
key = "MOT_PWM_TYPE"
print(f"{key}: {MOTPWMType(params.get(key)).name}")
# Out:
# FRAME_CLASS: Quad
# FRAME_TYPE: Plus
# MOT_PWM_TYPE: Normal

# %%
params
# Out:
# {'FORMAT_VERSION': 120.0,
#  'PILOT_THR_FILT': 0.0,
#  'PILOT_TKOFF_ALT': 0.0,
#  'PILOT_THR_BHV': 0.0,
#  'GCS_PID_MASK': 0.0,
#  'RTL_ALT': 1500.0,
#  'RTL_CONE_SLOPE': 3.0,
#  'RTL_SPEED': 0.0,
#  'RTL_ALT_FINAL': 0.0,
#  'RTL_CLIMB_MIN': 0.0,
#  'RTL_LOIT_TIME': 5000.0,
#  'RTL_ALT_TYPE': 0.0,
#  'FS_GCS_ENABLE': 0.0,
#  'GPS_HDOP_GOOD': 140.0,
#  'SUPER_SIMPLE': 0.0,
#  'WP_YAW_BEHAVIOR': 2.0,
#  'LAND_SPEED': 50.0,
#  'LAND_SPEED_HIGH': 0.0,
#  'PILOT_SPEED_UP': 250.0,
#  'PILOT_ACCEL_Z': 250.0,
#  'FS_THR_ENABLE': 1.0,
#  'FS_THR_VALUE': 975.0,
#  'THR_DZ': 100.0,
#  'FLTMODE1': 7.0,
#  'FLTMODE2': 9.0,
#  'FLTMODE3': 6.0,
#  'FLTMODE4': 3.0,
#  'FLTMODE5': 5.0,
#  'FLTMODE6': 0.0,
#  'FLTMODE_CH': 5.0,
#  'INITIAL_MODE': 0.0,
#  'SIMPLE': 0.0,
#  'LOG_BITMASK': 180222.0,
#  'ESC_CALIBRATION': 0.0,
#  'TUNE': 0.0,
#  'FRAME_TYPE': 0.0,
#  'ARMING_ACCTHRESH': 0.75,
#  'ARMING_RUDDER': 2.0,
#  'ARMING_MIS_ITEMS': 0.0,
#  'ARMING_CHECK': 1.0,
#  'ARMING_OPTIONS': 0.0,
#  'ARMING_MAGTHRESH': 100.0,
#  'ARMING_NEED_LOC': 0.0,
#  'DISARM_DELAY': 10.0,
#  'ANGLE_MAX': 3000.0,
#  'PHLD_BRAKE_RATE': 8.0,
#  'PHLD_BRAKE_ANGLE': 3000.0,
#  'LAND_REPOSITION': 1.0,
#  'FS_EKF_ACTION': 1.0,
#  'FS_EKF_THRESH': 0.800000011920929,
#  'FS_CRASH_CHECK': 1.0,
#  'RC_SPEED': 490.0,
#  'ACRO_BAL_ROLL': 1.0,
#  'ACRO_BAL_PITCH': 1.0,
#  'ACRO_TRAINER': 2.0,
#  'CAM_MAX_ROLL': 0.0,
#  'CAM_AUTO_ONLY': 0.0,
#  'CAM1_TYPE': 0.0,
#  'CAM2_TYPE': 0.0,
#  'RELAY1_FUNCTION': 1.0,
#  'RELAY1_PIN': 13.0,
#  'RELAY1_DEFAULT': 0.0,
#  'RELAY1_INVERTED': 0.0,
#  'RELAY2_FUNCTION': 0.0,
#  'RELAY3_FUNCTION': 0.0,
#  'RELAY4_FUNCTION': 0.0,
#  'RELAY5_FUNCTION': 0.0,
#  'RELAY6_FUNCTION': 0.0,
#  'CHUTE_ENABLED': 0.0,
#  'LGR_ENABLE': 0.0,
#  'COMPASS_OFS_X': 5.0,
#  'COMPASS_OFS_Y': 13.0,
#  'COMPASS_OFS_Z': -18.0,
#  'COMPASS_DEC': 0.0,
#  'COMPASS_LEARN': 0.0,
#  'COMPASS_USE': 1.0,
#  'COMPASS_AUTODEC': 1.0,
#  'COMPASS_MOTCT': 0.0,
#  'COMPASS_MOT_X': 0.0,
#  'COMPASS_MOT_Y': 0.0,
#  'COMPASS_MOT_Z': 0.0,
#  'COMPASS_ORIENT': 0.0,
#  'COMPASS_EXTERNAL': 1.0,
#  'COMPASS_OFS2_X': 5.0,
#  'COMPASS_OFS2_Y': 13.0,
#  'COMPASS_OFS2_Z': -18.0,
#  'COMPASS_MOT2_X': 0.0,
#  'COMPASS_MOT2_Y': 0.0,
#  'COMPASS_MOT2_Z': 0.0,
#  'COMPASS_OFS3_X': 5.0,
#  'COMPASS_OFS3_Y': 13.0,
#  'COMPASS_OFS3_Z': -18.0,
#  'COMPASS_MOT3_X': 0.0,
#  'COMPASS_MOT3_Y': 0.0,
#  'COMPASS_MOT3_Z': 0.0,
#  'COMPASS_DEV_ID': 97539.0,
#  'COMPASS_DEV_ID2': 131874.0,
#  'COMPASS_DEV_ID3': 263178.0,
#  'COMPASS_USE2': 1.0,
#  'COMPASS_ORIENT2': 0.0,
#  'COMPASS_EXTERN2': 0.0,
#  'COMPASS_USE3': 1.0,
#  'COMPASS_ORIENT3': 0.0,
#  'COMPASS_EXTERN3': 0.0,
#  'COMPASS_DIA_X': 1.0,
#  'COMPASS_DIA_Y': 1.0,
#  'COMPASS_DIA_Z': 1.0,
#  'COMPASS_ODI_X': 0.0,
#  'COMPASS_ODI_Y': 0.0,
#  'COMPASS_ODI_Z': 0.0,
#  'COMPASS_DIA2_X': 1.0,
#  'COMPASS_DIA2_Y': 1.0,
#  'COMPASS_DIA2_Z': 1.0,
#  'COMPASS_ODI2_X': 0.0,
#  'COMPASS_ODI2_Y': 0.0,
#  'COMPASS_ODI2_Z': 0.0,
#  'COMPASS_DIA3_X': 1.0,
#  'COMPASS_DIA3_Y': 1.0,
#  'COMPASS_DIA3_Z': 1.0,
#  'COMPASS_ODI3_X': 0.0,
#  'COMPASS_ODI3_Y': 0.0,
#  'COMPASS_ODI3_Z': 0.0,
#  'COMPASS_CAL_FIT': 16.0,
#  'COMPASS_OFFS_MAX': 1800.0,
#  'COMPASS_PMOT_EN': 0.0,
#  'COMPASS_DISBLMSK': 0.0,
#  'COMPASS_FLTR_RNG': 0.0,
#  'COMPASS_AUTO_ROT': 2.0,
#  'COMPASS_PRIO1_ID': 97539.0,
#  'COMPASS_PRIO2_ID': 131874.0,
#  'COMPASS_PRIO3_ID': 263178.0,
#  'COMPASS_ENABLE': 1.0,
#  'COMPASS_SCALE': 1.0,
#  'COMPASS_SCALE2': 1.0,
#  'COMPASS_SCALE3': 1.0,
#  'COMPASS_OPTIONS': 0.0,
#  'COMPASS_DEV_ID4': 97283.0,
#  'COMPASS_DEV_ID5': 97795.0,
#  'COMPASS_DEV_ID6': 98051.0,
#  'COMPASS_DEV_ID7': 0.0,
#  'COMPASS_DEV_ID8': 0.0,
#  'INS_GYROFFS_X': 2.3449767468264326e-05,
#  'INS_GYROFFS_Y': 2.5720370103954338e-05,
#  'INS_GYROFFS_Z': 2.9012084269197658e-05,
#  'INS_GYR2OFFS_X': 2.0153298464720137e-05,
#  'INS_GYR2OFFS_Y': 2.7733694878406823e-05,
#  'INS_GYR2OFFS_Z': 1.705062277324032e-05,
#  'INS_GYR3OFFS_X': 0.0,
#  'INS_GYR3OFFS_Y': 0.0,
#  'INS_GYR3OFFS_Z': 0.0,
#  'INS_ACCSCAL_X': 1.0010000467300415,
#  'INS_ACCSCAL_Y': 1.0010000467300415,
#  'INS_ACCSCAL_Z': 1.0010000467300415,
#  'INS_ACCOFFS_X': 0.0010000000474974513,
#  'INS_ACCOFFS_Y': 0.0010000000474974513,
#  'INS_ACCOFFS_Z': 0.0010000000474974513,
#  'INS_ACC2SCAL_X': 1.0010000467300415,
#  'INS_ACC2SCAL_Y': 1.0010000467300415,
#  'INS_ACC2SCAL_Z': 1.0010000467300415,
#  'INS_ACC2OFFS_X': 0.0010000000474974513,
#  'INS_ACC2OFFS_Y': 0.0010000000474974513,
#  'INS_ACC2OFFS_Z': 0.0010000000474974513,
#  'INS_ACC3SCAL_X': 1.0,
#  'INS_ACC3SCAL_Y': 1.0,
#  'INS_ACC3SCAL_Z': 1.0,
#  'INS_ACC3OFFS_X': 0.0,
#  'INS_ACC3OFFS_Y': 0.0,
#  'INS_ACC3OFFS_Z': 0.0,
#  'INS_GYRO_FILTER': 20.0,
#  'INS_ACCEL_FILTER': 20.0,
#  'INS_USE': 1.0,
#  'INS_USE2': 1.0,
#  'INS_USE3': 1.0,
#  'INS_STILL_THRESH': 2.5,
#  'INS_GYR_CAL': 1.0,
#  'INS_TRIM_OPTION': 1.0,
#  'INS_ACC_BODYFIX': 2.0,
#  'INS_POS1_X': 0.0,
#  'INS_POS1_Y': 0.0,
#  'INS_POS1_Z': 0.0,
#  'INS_POS2_X': 0.0,
#  'INS_POS2_Y': 0.0,
#  'INS_POS2_Z': 0.0,
#  'INS_POS3_X': 0.0,
#  'INS_POS3_Y': 0.0,
#  'INS_POS3_Z': 0.0,
#  'INS_GYR_ID': 2752772.0,
#  'INS_GYR2_ID': 2752780.0,
#  'INS_GYR3_ID': 0.0,
#  'INS_ACC_ID': 2753028.0,
#  'INS_ACC2_ID': 2753036.0,
#  'INS_ACC3_ID': 0.0,
#  'INS_FAST_SAMPLE': 1.0,
#  'INS_LOG_BAT_CNT': 1024.0,
#  'INS_LOG_BAT_MASK': 0.0,
#  'INS_LOG_BAT_OPT': 0.0,
#  'INS_LOG_BAT_LGIN': 20.0,
#  'INS_LOG_BAT_LGCT': 32.0,
#  'INS_ENABLE_MASK': 127.0,
#  'INS_HNTCH_ENABLE': 0.0,
#  'INS_HNTC2_ENABLE': 0.0,
#  'INS_GYRO_RATE': 0.0,
#  'INS_TCAL1_ENABLE': 0.0,
#  'INS_TCAL2_ENABLE': 0.0,
#  'INS_TCAL3_ENABLE': 0.0,
#  'INS_ACC1_CALTEMP': -300.0,
#  'INS_GYR1_CALTEMP': 25.018352508544922,
#  'INS_ACC2_CALTEMP': -300.0,
#  'INS_GYR2_CALTEMP': 25.018352508544922,
#  'INS_ACC3_CALTEMP': -300.0,
#  'INS_GYR3_CALTEMP': -300.0,
#  'INS_TCAL_OPTIONS': 0.0,
#  'INS_RAW_LOG_OPT': 0.0,
#  'WPNAV_SPEED': 1000.0,
#  'WPNAV_RADIUS': 200.0,
#  'WPNAV_SPEED_UP': 250.0,
#  'WPNAV_SPEED_DN': 150.0,
#  'WPNAV_ACCEL': 250.0,
#  'WPNAV_ACCEL_Z': 100.0,
#  'WPNAV_RFND_USE': 1.0,
#  'WPNAV_JERK': 1.0,
#  'WPNAV_TER_MARGIN': 10.0,
#  'WPNAV_ACCEL_C': 0.0,
#  'LOIT_ANG_MAX': 0.0,
#  'LOIT_SPEED': 1250.0,
#  'LOIT_ACC_MAX': 500.0,
#  'LOIT_BRK_ACCEL': 250.0,
#  'LOIT_BRK_JERK': 500.0,
#  'LOIT_BRK_DELAY': 1.0,
#  'CIRCLE_RADIUS': 1000.0,
#  'CIRCLE_RATE': 20.0,
#  'CIRCLE_OPTIONS': 1.0,
#  'ATC_SLEW_YAW': 6000.0,
#  'ATC_ACCEL_Y_MAX': 27000.0,
#  'ATC_RATE_FF_ENAB': 1.0,
#  'ATC_ACCEL_R_MAX': 110000.0,
#  'ATC_ACCEL_P_MAX': 110000.0,
#  'ATC_ANGLE_BOOST': 1.0,
#  'ATC_ANG_RLL_P': 4.5,
#  'ATC_ANG_PIT_P': 4.5,
#  'ATC_ANG_YAW_P': 4.5,
#  'ATC_ANG_LIM_TC': 1.0,
#  'ATC_RATE_R_MAX': 0.0,
#  'ATC_RATE_P_MAX': 0.0,
#  'ATC_RATE_Y_MAX': 0.0,
#  'ATC_INPUT_TC': 0.15000000596046448,
#  'ATC_LAND_R_MULT': 1.0,
#  'ATC_LAND_P_MULT': 1.0,
#  'ATC_LAND_Y_MULT': 1.0,
#  'ATC_RAT_RLL_P': 0.13500000536441803,
#  'ATC_RAT_RLL_I': 0.13500000536441803,
#  'ATC_RAT_RLL_D': 0.003599999938160181,
#  'ATC_RAT_RLL_FF': 0.0,
#  'ATC_RAT_RLL_IMAX': 0.5,
#  'ATC_RAT_RLL_FLTT': 20.0,
#  'ATC_RAT_RLL_FLTE': 0.0,
#  'ATC_RAT_RLL_FLTD': 20.0,
#  'ATC_RAT_RLL_SMAX': 0.0,
#  'ATC_RAT_RLL_PDMX': 0.0,
#  'ATC_RAT_RLL_D_FF': 0.0,
#  'ATC_RAT_RLL_NTF': 0.0,
#  'ATC_RAT_RLL_NEF': 0.0,
#  'ATC_RAT_PIT_P': 0.13500000536441803,
#  'ATC_RAT_PIT_I': 0.13500000536441803,
#  'ATC_RAT_PIT_D': 0.003599999938160181,
#  'ATC_RAT_PIT_FF': 0.0,
#  'ATC_RAT_PIT_IMAX': 0.5,
#  'ATC_RAT_PIT_FLTT': 20.0,
#  'ATC_RAT_PIT_FLTE': 0.0,
#  'ATC_RAT_PIT_FLTD': 20.0,
#  'ATC_RAT_PIT_SMAX': 0.0,
#  'ATC_RAT_PIT_PDMX': 0.0,
#  'ATC_RAT_PIT_D_FF': 0.0,
#  'ATC_RAT_PIT_NTF': 0.0,
#  'ATC_RAT_PIT_NEF': 0.0,
#  'ATC_RAT_YAW_P': 0.30000001192092896,
#  'ATC_RAT_YAW_I': 0.019999999552965164,
#  'ATC_RAT_YAW_D': 0.0,
#  'ATC_RAT_YAW_FF': 0.0,
#  'ATC_RAT_YAW_IMAX': 0.5,
#  'ATC_RAT_YAW_FLTT': 20.0,
#  'ATC_RAT_YAW_FLTE': 2.5,
#  'ATC_RAT_YAW_FLTD': 20.0,
#  'ATC_RAT_YAW_SMAX': 0.0,
#  'ATC_RAT_YAW_PDMX': 0.0,
#  'ATC_RAT_YAW_D_FF': 0.0,
#  'ATC_RAT_YAW_NTF': 0.0,
#  'ATC_RAT_YAW_NEF': 0.0,
#  'ATC_THR_MIX_MIN': 0.10000000149011612,
#  'ATC_THR_MIX_MAX': 0.5,
#  'ATC_THR_MIX_MAN': 0.10000000149011612,
#  'ATC_THR_G_BOOST': 0.0,
#  'PSC_POSZ_P': 1.0,
#  'PSC_VELZ_P': 5.0,
#  'PSC_VELZ_I': 0.0,
#  'PSC_VELZ_IMAX': 1000.0,
#  'PSC_VELZ_FLTE': 5.0,
#  'PSC_VELZ_D': 0.0,
#  'PSC_VELZ_FLTD': 5.0,
#  'PSC_VELZ_FF': 0.0,
#  'PSC_ACCZ_P': 0.5,
#  'PSC_ACCZ_I': 1.0,
#  'PSC_ACCZ_D': 0.0,
#  'PSC_ACCZ_FF': 0.0,
#  'PSC_ACCZ_IMAX': 800.0,
#  'PSC_ACCZ_FLTT': 0.0,
#  'PSC_ACCZ_FLTE': 20.0,
#  'PSC_ACCZ_FLTD': 0.0,
#  'PSC_ACCZ_SMAX': 0.0,
#  'PSC_ACCZ_PDMX': 0.0,
#  'PSC_ACCZ_D_FF': 0.0,
#  'PSC_ACCZ_NTF': 0.0,
#  'PSC_ACCZ_NEF': 0.0,
#  'PSC_POSXY_P': 1.0,
#  'PSC_VELXY_P': 2.0,
#  'PSC_VELXY_I': 1.0,
#  'PSC_VELXY_IMAX': 1000.0,
#  'PSC_VELXY_FLTE': 5.0,
#  'PSC_VELXY_D': 0.5,
#  'PSC_VELXY_FLTD': 5.0,
#  'PSC_VELXY_FF': 0.0,
#  'PSC_ANGLE_MAX': 0.0,
#  'PSC_JERK_XY': 5.0,
#  'PSC_JERK_Z': 5.0,
#  'AHRS_GPS_GAIN': 1.0,
#  'AHRS_GPS_USE': 1.0,
#  'AHRS_YAW_P': 0.20000000298023224,
#  'AHRS_RP_P': 0.20000000298023224,
#  'AHRS_WIND_MAX': 0.0,
#  'AHRS_TRIM_X': 0.0,
#  'AHRS_TRIM_Y': 0.0,
#  'AHRS_TRIM_Z': 0.0,
#  'AHRS_ORIENTATION': 0.0,
#  'AHRS_COMP_BETA': 0.10000000149011612,
#  'AHRS_GPS_MINSATS': 6.0,
#  'AHRS_EKF_TYPE': 3.0,
#  'AHRS_OPTIONS': 0.0,
#  'MNT1_TYPE': 0.0,
#  'MNT2_TYPE': 0.0,
#  'BATT_MONITOR': 4.0,
#  'BATT_CAPACITY': 3300.0,
#  'BATT_SERIAL_NUM': -1.0,
#  'BATT_LOW_TIMER': 10.0,
#  'BATT_FS_VOLTSRC': 0.0,
#  'BATT_LOW_VOLT': 10.5,
#  'BATT_LOW_MAH': 0.0,
#  'BATT_CRT_VOLT': 0.0,
#  'BATT_CRT_MAH': 0.0,
#  'BATT_FS_LOW_ACT': 0.0,
#  'BATT_FS_CRT_ACT': 0.0,
#  'BATT_ARM_VOLT': 0.0,
#  'BATT_ARM_MAH': 0.0,
#  'BATT_OPTIONS': 0.0,
#  'BATT_VOLT_PIN': 13.0,
#  'BATT_CURR_PIN': 12.0,
#  'BATT_VOLT_MULT': 10.100000381469727,
#  'BATT_AMP_PERVLT': 17.0,
#  'BATT_AMP_OFFSET': 0.0,
#  'BATT_VLT_OFFSET': 0.0,
#  'BATT2_MONITOR': 0.0,
#  'BATT3_MONITOR': 0.0,
#  'BATT4_MONITOR': 0.0,
#  'BATT5_MONITOR': 0.0,
#  'BATT6_MONITOR': 0.0,
#  'BATT7_MONITOR': 0.0,
#  'BATT8_MONITOR': 0.0,
#  'BATT9_MONITOR': 0.0,
#  'BRD_SAFETY_DEFLT': 0.0,
#  'BRD_SERIAL_NUM': 0.0,
#  'BRD_SAFETY_MASK': 16368.0,
#  'BRD_SAFETYOPTION': 3.0,
#  'BRD_RTC_TYPES': 1.0,
#  'BRD_RTC_TZ_MIN': 0.0,
#  'BRD_VBUS_MIN': 4.300000190734863,
#  'BRD_VSERVO_MIN': 0.0,
#  'BRD_OPTIONS': 0.0,
#  'BRD_BOOT_DELAY': 0.0,
#  'BRD_SD_MISSION': 0.0,
#  'BRD_SD_FENCE': 0.0,
#  'CAN_P1_DRIVER': 0.0,
#  'CAN_P2_DRIVER': 0.0,
#  'CAN_D1_PROTOCOL': 1.0,
#  'CAN_D1_PROTOCOL2': 0.0,
#  'CAN_D2_PROTOCOL': 1.0,
#  'CAN_D2_PROTOCOL2': 0.0,
#  'CAN_LOGLEVEL': 0.0,
#  'SPRAY_ENABLE': 0.0,
#  'SIM_DRIFT_SPEED': 0.05000000074505806,
#  'SIM_DRIFT_TIME': 5.0,
#  'SIM_ENGINE_MUL': 0.0,
#  'SIM_WIND_SPD': 0.0,
#  'SIM_WIND_DIR': 180.0,
#  'SIM_WIND_TURB': 0.0,
#  'SIM_WIND_TC': 5.0,
#  'SIM_SERVO_SPEED': 0.14000000059604645,
#  'SIM_SERVO_DELAY': 0.0,
#  'SIM_SERVO_FILTER': 0.0,
#  'SIM_SONAR_ROT': 25.0,
#  'SIM_BATT_VOLTAGE': 12.600000381469727,
#  'SIM_BATT_CAP_AH': 0.0,
#  'SIM_SONAR_GLITCH': 0.0,
#  'SIM_SONAR_RND': 0.0,
#  'SIM_RC_FAIL': 0.0,
#  'SIM_FLOAT_EXCEPT': 1.0,
#  'SIM_CAN_SRV_MSK': 0.0,
#  'SIM_CAN_TYPE1': 1.0,
#  'SIM_CAN_TYPE2': 1.0,
#  'SIM_SONAR_SCALE': 12.121199607849121,
#  'SIM_FLOW_ENABLE': 0.0,
#  'SIM_TERRAIN': 1.0,
#  'SIM_FLOW_RATE': 10.0,
#  'SIM_FLOW_DELAY': 0.0,
#  'SIM_ADSB_COUNT': -1.0,
#  'SIM_ADSB_RADIUS': 10000.0,
#  'SIM_ADSB_ALT': 1000.0,
#  'SIM_PIN_MASK': 0.0,
#  'SIM_ADSB_TX': 0.0,
#  'SIM_SPEEDUP': 1.0,
#  'SIM_IMU_POS_X': 0.0,
#  'SIM_IMU_POS_Y': 0.0,
#  'SIM_IMU_POS_Z': 0.0,
#  'SIM_IMUT_START': 25.0,
#  'SIM_IMUT_END': 45.0,
#  'SIM_IMUT_TCONST': 300.0,
#  'SIM_IMUT_FIXED': 0.0,
#  'SIM_ACC1_BIAS_X': 0.0,
#  'SIM_ACC1_BIAS_Y': 0.0,
#  'SIM_ACC1_BIAS_Z': 0.0,
#  'SIM_ACC2_BIAS_X': 0.0,
#  'SIM_ACC2_BIAS_Y': 0.0,
#  'SIM_ACC2_BIAS_Z': 0.0,
#  'SIM_ACC3_BIAS_X': 0.0,
#  'SIM_ACC3_BIAS_Y': 0.0,
#  'SIM_ACC3_BIAS_Z': 0.0,
#  'SIM_GYR1_RND': 0.0,
#  'SIM_GYR2_RND': 0.0,
#  'SIM_GYR3_RND': 0.0,
#  'SIM_ACC1_RND': 0.0,
#  'SIM_ACC2_RND': 0.0,
#  'SIM_ACC3_RND': 0.0,
#  'SIM_GYR1_SCALE_X': 0.0,
#  'SIM_GYR1_SCALE_Y': 0.0,
#  'SIM_GYR1_SCALE_Z': 0.0,
#  'SIM_GYR2_SCALE_X': 0.0,
#  'SIM_GYR2_SCALE_Y': 0.0,
#  'SIM_GYR2_SCALE_Z': 0.0,
#  'SIM_GYR3_SCALE_X': 0.0,
#  'SIM_GYR3_SCALE_Y': 0.0,
#  'SIM_GYR3_SCALE_Z': 0.0,
#  'SIM_ACCEL1_FAIL': 0.0,
#  'SIM_ACCEL2_FAIL': 0.0,
#  'SIM_ACCEL3_FAIL': 0.0,
#  'SIM_GYR_FAIL_MSK': 0.0,
#  'SIM_ACC_FAIL_MSK': 0.0,
#  'SIM_ACC1_SCAL_X': 0.0,
#  'SIM_ACC1_SCAL_Y': 0.0,
#  'SIM_ACC1_SCAL_Z': 0.0,
#  'SIM_ACC2_SCAL_X': 0.0,
#  'SIM_ACC2_SCAL_Y': 0.0,
#  'SIM_ACC2_SCAL_Z': 0.0,
#  'SIM_ACC3_SCAL_X': 0.0,
#  'SIM_ACC3_SCAL_Y': 0.0,
#  'SIM_ACC3_SCAL_Z': 0.0,
#  'SIM_ACC_TRIM_X': 0.0,
#  'SIM_ACC_TRIM_Y': 0.0,
#  'SIM_ACC_TRIM_Z': 0.0,
#  'SIM_JSON_MASTER': 0.0,
#  'SIM_OH_MASK': 0.0,
#  'SIM_GYR_FILE_RW': 0.0,
#  'SIM_ACC_FILE_RW': 0.0,
#  'SIM_GYR1_BIAS_X': 0.0,
#  'SIM_GYR1_BIAS_Y': 0.0,
#  'SIM_GYR1_BIAS_Z': 0.0,
#  'SIM_GYR2_BIAS_X': 0.0,
#  'SIM_GYR2_BIAS_Y': 0.0,
#  'SIM_GYR2_BIAS_Z': 0.0,
#  'SIM_GYR3_BIAS_X': 0.0,
#  'SIM_GYR3_BIAS_Y': 0.0,
#  'SIM_GYR3_BIAS_Z': 0.0,
#  'SIM_OH_RELAY_MSK': -1.0,
#  'SIM_CLAMP_CH': 0.0,
#  'SIM_IMUT1_ENABLE': 0.0,
#  'SIM_IMUT2_ENABLE': 0.0,
#  'SIM_IMUT3_ENABLE': 0.0,
#  'SIM_SONAR_POS_X': 0.0,
#  'SIM_SONAR_POS_Y': 0.0,
#  'SIM_SONAR_POS_Z': 0.0,
#  'SIM_FLOW_POS_X': 0.0,
#  'SIM_FLOW_POS_Y': 0.0,
#  'SIM_FLOW_POS_Z': 0.0,
#  'SIM_ENGINE_FAIL': 0.0,
#  'SIM_SHIP_ENABLE': 0.0,
#  'SIM_SHIP_SPEED': 3.0,
#  'SIM_SHIP_PSIZE': 1000.0,
#  'SIM_SHIP_SYSID': 17.0,
#  'SIM_SHIP_DSIZE': 10.0,
#  'SIM_SHIP_OFS_X': 0.0,
#  'SIM_SHIP_OFS_Y': 0.0,
#  'SIM_SHIP_OFS_Z': 0.0,
#  'SIM_SLUP_ENABLE': 0.0,
#  'SIM_TETH_ENABLE': 0.0,
#  'SIM_MAG_RND': 0.0,
#  'SIM_MAG_MOT_X': 0.0,
#  'SIM_MAG_MOT_Y': 0.0,
#  'SIM_MAG_MOT_Z': 0.0,
#  'SIM_MAG_DELAY': 0.0,
#  'SIM_MAG1_OFS_X': 5.0,
#  'SIM_MAG1_OFS_Y': 13.0,
#  'SIM_MAG1_OFS_Z': -18.0,
#  'SIM_MAG_ALY_X': 0.0,
#  'SIM_MAG_ALY_Y': 0.0,
#  'SIM_MAG_ALY_Z': 0.0,
#  'SIM_MAG_ALY_HGT': 1.0,
#  'SIM_MAG1_DIA_X': 0.0,
#  'SIM_MAG1_DIA_Y': 0.0,
#  'SIM_MAG1_DIA_Z': 0.0,
#  'SIM_MAG1_ODI_X': 0.0,
#  'SIM_MAG1_ODI_Y': 0.0,
#  'SIM_MAG1_ODI_Z': 0.0,
#  'SIM_MAG1_ORIENT': 0.0,
#  'SIM_MAG1_SCALING': 1.0,
#  'SIM_MAG1_DEVID': 97539.0,
#  'SIM_MAG2_DEVID': 131874.0,
#  'SIM_MAG3_DEVID': 263178.0,
#  'SIM_MAG4_DEVID': 97283.0,
#  'SIM_MAG5_DEVID': 97795.0,
#  'SIM_MAG6_DEVID': 98051.0,
#  'SIM_MAG7_DEVID': 0.0,
#  'SIM_MAG8_DEVID': 0.0,
#  'SIM_MAG1_FAIL': 0.0,
#  'SIM_MAG2_OFS_X': 5.0,
#  'SIM_MAG2_OFS_Y': 13.0,
#  'SIM_MAG2_OFS_Z': -18.0,
#  'SIM_MAG2_DIA_X': 0.0,
#  'SIM_MAG2_DIA_Y': 0.0,
#  'SIM_MAG2_DIA_Z': 0.0,
#  'SIM_MAG2_ODI_X': 0.0,
#  'SIM_MAG2_ODI_Y': 0.0,
#  'SIM_MAG2_ODI_Z': 0.0,
#  'SIM_MAG2_ORIENT': 0.0,
#  'SIM_MAG2_FAIL': 0.0,
#  'SIM_MAG2_SCALING': 1.0,
#  'SIM_MAG3_OFS_X': 5.0,
#  'SIM_MAG3_OFS_Y': 13.0,
#  'SIM_MAG3_OFS_Z': -18.0,
#  'SIM_MAG3_DIA_X': 0.0,
#  'SIM_MAG3_DIA_Y': 0.0,
#  'SIM_MAG3_DIA_Z': 0.0,
#  'SIM_MAG3_ODI_X': 0.0,
#  'SIM_MAG3_ODI_Y': 0.0,
#  'SIM_MAG3_ODI_Z': 0.0,
#  'SIM_MAG3_FAIL': 0.0,
#  'SIM_MAG3_SCALING': 1.0,
#  'SIM_MAG3_ORIENT': 0.0,
#  'SIM_MAG_SAVE_IDS': 1.0,
#  'SIM_INIT_LAT_OFS': 0.0,
#  'SIM_INIT_LON_OFS': 0.0,
#  'SIM_INIT_ALT_OFS': 0.0,
#  'SIM_GPS_LOG_NUM': 0.0,
#  'SIM_GPS1_ENABLE': 1.0,
#  'SIM_GPS1_LAG_MS': 100.0,
#  'SIM_GPS1_TYPE': 1.0,
#  'SIM_GPS1_BYTELOS': 0.0,
#  'SIM_GPS1_NUMSATS': 10.0,
#  'SIM_GPS1_GLTCH_X': 0.0,
#  'SIM_GPS1_GLTCH_Y': 0.0,
#  'SIM_GPS1_GLTCH_Z': 0.0,
#  'SIM_GPS1_HZ': 5.0,
#  'SIM_GPS1_DRFTALT': 0.0,
#  'SIM_GPS1_POS_X': 0.0,
#  'SIM_GPS1_POS_Y': 0.0,
#  'SIM_GPS1_POS_Z': 0.0,
#  'SIM_GPS1_NOISE': 0.0,
#  'SIM_GPS1_LCKTIME': 0.0,
#  'SIM_GPS1_ALT_OFS': 0.0,
#  'SIM_GPS1_HDG': 0.0,
#  'SIM_GPS1_ACC': 0.30000001192092896,
#  'SIM_GPS1_VERR_X': 0.0,
#  'SIM_GPS1_VERR_Y': 0.0,
#  'SIM_GPS1_VERR_Z': 0.0,
#  'SIM_GPS1_JAM': 0.0,
#  'SIM_GPS2_ENABLE': 0.0,
#  'SIM_GPS3_ENABLE': 0.0,
#  'SIM_GPS4_ENABLE': 0.0,
#  'SIM_ODOM_ENABLE': 0.0,
#  'SIM_LED_LAYOUT': 0.0,
#  'SIM_THML_SCENARI': 0.0,
#  'SIM_VICON_POS_X': 0.0,
#  'SIM_VICON_POS_Y': 0.0,
#  'SIM_VICON_POS_Z': 0.0,
#  'SIM_VICON_GLIT_X': 0.0,
#  'SIM_VICON_GLIT_Y': 0.0,
#  'SIM_VICON_GLIT_Z': 0.0,
#  'SIM_VICON_FAIL': 0.0,
#  'SIM_VICON_YAW': 0.0,
#  'SIM_VICON_YAWERR': 0.0,
#  'SIM_VICON_TMASK': 3.0,
#  'SIM_VICON_VGLI_X': 0.0,
#  'SIM_VICON_VGLI_Y': 0.0,
#  'SIM_VICON_VGLI_Z': 0.0,
#  'SIM_RATE_HZ': 1200.0,
#  'SIM_IMU_COUNT': 2.0,
#  'SIM_FTOWESC_ENA': 0.0,
#  'SIM_FTOWESC_POW': 4095.0,
#  'SIM_RICH_ENABLE': 0.0,
#  'SIM_RICH_CTRL': -1.0,
#  'SIM_IE24_ENABLE': 0.0,
#  'SIM_IE24_STATE': -1.0,
#  'SIM_IE24_ERROR': 0.0,
#  'SIM_BARO_COUNT': 2.0,
#  'SIM_BARO_RND': 0.0,
#  'SIM_BARO_DRIFT': 0.0,
#  'SIM_BARO_DISABLE': 0.0,
#  'SIM_BARO_GLITCH': 0.0,
#  'SIM_BARO_FREEZE': 0.0,
#  'SIM_BARO_DELAY': 0.0,
#  'SIM_BARO_WCF_FWD': 0.0,
#  'SIM_BARO_WCF_BAK': 0.0,
#  'SIM_BARO_WCF_RGT': 0.0,
#  'SIM_BARO_WCF_LFT': 0.0,
#  'SIM_BARO_WCF_UP': 0.0,
#  'SIM_BARO_WCF_DN': 0.0,
#  'SIM_BAR2_RND': 0.20000000298023224,
#  'SIM_BAR2_DRIFT': 0.0,
#  'SIM_BAR2_DISABLE': 0.0,
#  'SIM_BAR2_GLITCH': 0.0,
#  'SIM_BAR2_FREEZE': 0.0,
#  'SIM_BAR2_DELAY': 0.0,
#  'SIM_BAR2_WCF_FWD': 0.0,
#  'SIM_BAR2_WCF_BAK': 0.0,
#  'SIM_BAR2_WCF_RGT': 0.0,
#  'SIM_BAR2_WCF_LFT': 0.0,
#  'SIM_BAR2_WCF_UP': 0.0,
#  'SIM_BAR2_WCF_DN': 0.0,
#  'SIM_BAR3_RND': 0.20000000298023224,
#  'SIM_BAR3_DRIFT': 0.0,
#  'SIM_BAR3_DISABLE': 0.0,
#  'SIM_BAR3_GLITCH': 0.0,
#  'SIM_BAR3_FREEZE': 0.0,
#  'SIM_BAR3_DELAY': 0.0,
#  'SIM_BAR3_WCF_FWD': 0.0,
#  'SIM_BAR3_WCF_BAK': 0.0,
#  'SIM_BAR3_WCF_RGT': 0.0,
#  'SIM_BAR3_WCF_LFT': 0.0,
#  'SIM_BAR3_WCF_UP': 0.0,
#  'SIM_BAR3_WCF_DN': 0.0,
#  'SIM_TIME_JITTER': 0.0,
#  'SIM_ESC_TELEM': 1.0,
#  'SIM_ESC_ARM_RPM': 0.0,
#  'SIM_UART_LOSS': 0.0,
#  'SIM_ARSPD_RND': 2.0,
#  'SIM_ARSPD_OFS': 2013.0,
#  'SIM_ARSPD_FAIL': 0.0,
#  'SIM_ARSPD_FAILP': 0.0,
#  'SIM_ARSPD_PITOT': 0.0,
#  'SIM_ARSPD_SIGN': 0.0,
#  'SIM_ARSPD_RATIO': 1.9900000095367432,
#  'SIM_ARSPD2_RND': 2.0,
#  'SIM_ARSPD2_OFS': 2013.0,
#  'SIM_ARSPD2_FAIL': 0.0,
#  'SIM_ARSPD2_FAILP': 0.0,
#  'SIM_ARSPD2_PITOT': 0.0,
#  'SIM_ARSPD2_SIGN': 0.0,
#  'SIM_ARSPD2_RATIO': 1.9900000095367432,
#  'SIM_ADSB_TYPES': 1.0,
#  'SIM_VOLZ_ENA': 0.0,
#  'SIM_VOLZ_MASK': 11.0,
#  'SIM_VOLZ_FMASK': 0.0,
#  'SIM_TEMP_START': 25.0,
#  'SIM_TEMP_BRD_OFF': 20.0,
#  'SIM_TEMP_TCONST': 30.0,
#  'SIM_TEMP_BFACTOR': 0.0,
#  'SIM_WIND_DIR_Z': 0.0,
#  'SIM_WIND_T': 0.0,
#  'SIM_WIND_T_ALT': 60.0,
#  'SIM_WIND_T_COEF': 0.009999999776482582,
#  'SIM_RC_CHANCOUNT': 16.0,
#  'SIM_SPR_ENABLE': 0.0,
#  'SIM_SPR_PUMP': -1.0,
#  'SIM_SPR_SPIN': -1.0,
#  'SIM_GRPS_ENABLE': 0.0,
#  'SIM_GRPS_PIN': -1.0,
#  'SIM_GRPS_GRAB': 2000.0,
#  'SIM_GRPS_RELEASE': 1000.0,
#  'SIM_GRPS_REVERSE': 0.0,
#  'SIM_GRPE_ENABLE': 0.0,
#  'SIM_GRPE_PIN': -1.0,
#  'SIM_WOW_PIN': -1.0,
#  'SIM_VIB_FREQ_X': 0.0,
#  'SIM_VIB_FREQ_Y': 0.0,
#  'SIM_VIB_FREQ_Z': 0.0,
#  'SIM_PARA_ENABLE': 0.0,
#  'SIM_PARA_PIN': -1.0,
#  'SIM_BAUDLIMIT_EN': 0.0,
#  'SIM_PLD_ENABLE': 0.0,
#  'SIM_PLD_LAT': -35.36332702636719,
#  'SIM_PLD_LON': 149.16522216796875,
#  'SIM_PLD_HEIGHT': 0.0,
#  'SIM_PLD_YAW': 0.0,
#  'SIM_PLD_RATE': 100.0,
#  'SIM_PLD_TYPE': 0.0,
#  'SIM_PLD_ALT_LMT': 15.0,
#  'SIM_PLD_DIST_LMT': 10.0,
#  'SIM_PLD_ORIENT': 24.0,
#  'SIM_PLD_OPTIONS': 0.0,
#  'SIM_PLD_SHIP': 0.0,
#  'SIM_SHOVE_X': 0.0,
#  'SIM_SHOVE_Y': 0.0,
#  'SIM_SHOVE_Z': 0.0,
#  'SIM_SHOVE_TIME': 0.0,
#  'SIM_FLOW_RND': 0.05000000074505806,
#  'SIM_TWIST_X': 0.0,
#  'SIM_TWIST_Y': 0.0,
#  'SIM_TWIST_Z': 0.0,
#  'SIM_TWIST_TIME': 0.0,
#  'SIM_GND_BEHAV': -1.0,
#  'SIM_IMU_ORIENT': 0.0,
#  'SIM_WAVE_ENABLE': 0.0,
#  'SIM_WAVE_LENGTH': 10.0,
#  'SIM_WAVE_AMP': 0.5,
#  'SIM_WAVE_DIR': 0.0,
#  'SIM_WAVE_SPEED': 0.5,
#  'SIM_TIDE_DIR': 0.0,
#  'SIM_TIDE_SPEED': 0.0,
#  'SIM_OPOS_LAT': -35.36326217651367,
#  'SIM_OPOS_LNG': 149.1652374267578,
#  'SIM_OPOS_ALT': 584.0,
#  'SIM_OPOS_HDG': 353.0,
#  'SIM_LOOP_DELAY': 0.0,
#  'SIM_TA_ENABLE': 1.0,
#  'SIM_EFI_TYPE': 0.0,
#  'SIM_VIB_MOT_HMNC': 1.0,
#  'SIM_VIB_MOT_MASK': 0.0,
#  'SIM_VIB_MOT_MAX': 0.0,
#  'SIM_INS_THR_MIN': 0.10000000149011612,
#  'SIM_VIB_MOT_MULT': 1.0,
#  'BARO1_GND_PRESS': 101323.84375,
#  'BARO_GND_TEMP': 0.0,
#  'BARO_ALT_OFFSET': 0.0,
#  'BARO_PRIMARY': 0.0,
#  'BARO_EXT_BUS': -1.0,
#  'BARO2_GND_PRESS': 101323.5234375,
#  'BARO3_GND_PRESS': 0.0,
#  'BARO_FLTR_RNG': 0.0,
#  'BARO_PROBE_EXT': 0.0,
#  'BARO1_DEVID': 65540.0,
#  'BARO2_DEVID': 65796.0,
#  'BARO3_DEVID': 0.0,
#  'BARO1_WCF_ENABLE': 0.0,
#  'BARO2_WCF_ENABLE': 0.0,
#  'BARO3_WCF_ENABLE': 0.0,
#  'BARO_FIELD_ELV': 0.0,
#  'BARO_ALTERR_MAX': 2000.0,
#  'BARO_OPTIONS': 0.0,
#  'GPS_NAVFILTER': 8.0,
#  'GPS_AUTO_SWITCH': 1.0,
#  'GPS_SBAS_MODE': 2.0,
#  'GPS_MIN_ELEV': -100.0,
#  'GPS_INJECT_TO': 127.0,
#  'GPS_SBP_LOGMASK': -256.0,
#  'GPS_RAW_DATA': 0.0,
#  'GPS_SAVE_CFG': 2.0,
#  'GPS_AUTO_CONFIG': 1.0,
#  'GPS_BLEND_MASK': 5.0,
#  'GPS_DRV_OPTIONS': 0.0,
#  'GPS_PRIMARY': 0.0,
#  'GPS1_TYPE': 1.0,
#  'GPS1_GNSS_MODE': 0.0,
#  'GPS1_RATE_MS': 200.0,
#  'GPS1_POS_X': 0.0,
#  'GPS1_POS_Y': 0.0,
#  'GPS1_POS_Z': 0.0,
#  'GPS1_DELAY_MS': 0.0,
#  'GPS1_COM_PORT': 1.0,
#  'GPS1_MB_TYPE': 0.0,
#  'GPS1_CAN_NODEID': 0.0,
#  'GPS1_CAN_OVRIDE': 0.0,
#  'GPS2_TYPE': 0.0,
#  'SCHED_DEBUG': 0.0,
#  'SCHED_LOOP_RATE': 400.0,
#  'SCHED_OPTIONS': 0.0,
#  'AVOID_ENABLE': 3.0,
#  'AVOID_ANGLE_MAX': 1000.0,
#  'AVOID_DIST_MAX': 5.0,
#  'AVOID_MARGIN': 2.0,
#  'AVOID_BEHAVE': 0.0,
#  'AVOID_BACKUP_SPD': 0.75,
#  'AVOID_ALT_MIN': 0.0,
#  'AVOID_ACCEL_MAX': 3.0,
#  'AVOID_BACKUP_DZ': 0.10000000149011612,
#  'AVOID_BACKZ_SPD': 0.75,
#  'RALLY_TOTAL': 0.0,
#  'RALLY_LIMIT_KM': 0.30000001192092896,
#  'RALLY_INCL_HOME': 1.0,
#  'MOT_YAW_HEADROOM': 200.0,
#  'MOT_THST_EXPO': 0.6499999761581421,
#  'MOT_SPIN_MAX': 0.949999988079071,
#  'MOT_BAT_VOLT_MAX': 12.800000190734863,
#  'MOT_BAT_VOLT_MIN': 9.600000381469727,
#  'MOT_BAT_CURR_MAX': 0.0,
#  'MOT_PWM_TYPE': 0.0,
#  'MOT_PWM_MIN': 1000.0,
#  'MOT_PWM_MAX': 2000.0,
#  'MOT_SPIN_MIN': 0.15000000596046448,
#  'MOT_SPIN_ARM': 0.10000000149011612,
#  'MOT_BAT_CURR_TC': 5.0,
#  'MOT_THST_HOVER': 0.38999998569488525,
#  'MOT_HOVER_LEARN': 2.0,
#  'MOT_SAFE_DISARM': 0.0,
#  'MOT_SPOOL_TIME': 0.5,
#  'MOT_BOOST_SCALE': 0.0,
#  'MOT_BAT_IDX': 0.0,
#  'MOT_SLEW_UP_TIME': 0.0,
#  'MOT_SLEW_DN_TIME': 0.0,
#  'MOT_SAFE_TIME': 1.0,
#  'MOT_OPTIONS': 0.0,
#  'MOT_SPOOL_TIM_DN': 0.0,
#  'RCMAP_ROLL': 1.0,
#  'RCMAP_PITCH': 2.0,
#  'RCMAP_THROTTLE': 3.0,
#  'RCMAP_YAW': 4.0,
#  'EK2_ENABLE': 0.0,
#  'EK3_ENABLE': 1.0,
#  'EK3_VELNE_M_NSE': 0.30000001192092896,
#  'EK3_VELD_M_NSE': 0.5,
#  'EK3_VEL_I_GATE': 500.0,
#  'EK3_POSNE_M_NSE': 0.5,
#  'EK3_POS_I_GATE': 500.0,
#  'EK3_GLITCH_RAD': 25.0,
#  'EK3_ALT_M_NSE': 2.0,
#  'EK3_HGT_I_GATE': 500.0,
#  'EK3_HGT_DELAY': 60.0,
#  'EK3_MAG_M_NSE': 0.05000000074505806,
#  'EK3_MAG_CAL': 3.0,
#  'EK3_MAG_I_GATE': 300.0,
#  'EK3_EAS_M_NSE': 1.399999976158142,
#  'EK3_EAS_I_GATE': 400.0,
#  'EK3_RNG_M_NSE': 0.5,
#  'EK3_RNG_I_GATE': 500.0,
#  'EK3_MAX_FLOW': 2.5,
#  'EK3_FLOW_M_NSE': 0.25,
#  'EK3_FLOW_I_GATE': 300.0,
#  'EK3_FLOW_DELAY': 10.0,
#  'EK3_GYRO_P_NSE': 0.014999999664723873,
#  'EK3_ACC_P_NSE': 0.3499999940395355,
#  'EK3_GBIAS_P_NSE': 0.0010000000474974513,
#  'EK3_ABIAS_P_NSE': 0.019999999552965164,
#  'EK3_WIND_P_NSE': 0.20000000298023224,
#  'EK3_WIND_PSCALE': 1.0,
#  'EK3_GPS_CHECK': 31.0,
#  'EK3_IMU_MASK': 3.0,
#  'EK3_CHECK_SCALE': 100.0,
#  'EK3_NOAID_M_NSE': 10.0,
#  'EK3_BETA_MASK': 0.0,
#  'EK3_YAW_M_NSE': 0.5,
#  'EK3_YAW_I_GATE': 300.0,
#  'EK3_TAU_OUTPUT': 25.0,
#  'EK3_MAGE_P_NSE': 0.0010000000474974513,
#  'EK3_MAGB_P_NSE': 9.999999747378752e-05,
#  'EK3_RNG_USE_HGT': -1.0,
#  'EK3_TERR_GRAD': 0.10000000149011612,
#  'EK3_BCN_M_NSE': 1.0,
#  'EK3_BCN_I_GTE': 500.0,
#  'EK3_BCN_DELAY': 50.0,
#  'EK3_RNG_USE_SPD': 2.0,
#  'EK3_ACC_BIAS_LIM': 1.0,
#  'EK3_MAG_MASK': 0.0,
#  'EK3_OGN_HGT_MASK': 0.0,
#  'EK3_VIS_VERR_MIN': 0.10000000149011612,
#  'EK3_VIS_VERR_MAX': 0.8999999761581421,
#  'EK3_WENC_VERR': 0.10000000149011612,
#  'EK3_FLOW_USE': 1.0,
#  'EK3_HRT_FILT': 2.0,
#  'EK3_MAG_EF_LIM': 50.0,
#  'EK3_GSF_RUN_MASK': 3.0,
#  'EK3_GSF_USE_MASK': 3.0,
#  'EK3_GSF_RST_MAX': 2.0,
#  'EK3_ERR_THRESH': 0.20000000298023224,
#  'EK3_AFFINITY': 0.0,
#  'EK3_SRC1_POSXY': 3.0,
#  'EK3_SRC1_VELXY': 3.0,
#  'EK3_SRC1_POSZ': 1.0,
#  'EK3_SRC1_VELZ': 3.0,
#  'EK3_SRC1_YAW': 1.0,
#  'EK3_SRC2_POSXY': 0.0,
#  'EK3_SRC2_VELXY': 0.0,
#  'EK3_SRC2_POSZ': 1.0,
#  'EK3_SRC2_VELZ': 0.0,
#  'EK3_SRC2_YAW': 0.0,
#  'EK3_SRC3_POSXY': 0.0,
#  'EK3_SRC3_VELXY': 0.0,
#  'EK3_SRC3_POSZ': 1.0,
#  'EK3_SRC3_VELZ': 0.0,
#  'EK3_SRC3_YAW': 0.0,
#  'EK3_SRC_OPTIONS': 1.0,
#  'EK3_DRAG_BCOEF_X': 0.0,
#  'EK3_DRAG_BCOEF_Y': 0.0,
#  'EK3_DRAG_M_NSE': 0.5,
#  'EK3_DRAG_MCOEF': 0.0,
#  'EK3_OGNM_TEST_SF': 2.0,
#  'EK3_GND_EFF_DZ': 4.0,
#  'EK3_PRIMARY': 0.0,
#  'EK3_LOG_LEVEL': 0.0,
#  'EK3_GPS_VACC_MAX': 0.0,
#  'EK3_OPTIONS': 0.0,
#  'MIS_TOTAL': 0.0,
#  'MIS_RESTART': 0.0,
#  'MIS_OPTIONS': 0.0,
#  'RSSI_TYPE': 0.0,
#  'RNGFND1_TYPE': 0.0,
#  'RNGFND2_TYPE': 0.0,
#  'RNGFND3_TYPE': 0.0,
#  'RNGFND4_TYPE': 0.0,
#  'RNGFND5_TYPE': 0.0,
#  'RNGFND6_TYPE': 0.0,
#  'RNGFND7_TYPE': 0.0,
#  'RNGFND8_TYPE': 0.0,
#  'RNGFND9_TYPE': 0.0,
#  'RNGFNDA_TYPE': 0.0,
#  'TERRAIN_ENABLE': 1.0,
#  'TERRAIN_SPACING': 100.0,
#  'TERRAIN_OPTIONS': 0.0,
#  'TERRAIN_MARGIN': 0.05000000074505806,
#  'TERRAIN_OFS_MAX': 30.0,
#  'TERRAIN_CACHE_SZ': 12.0,
#  'FLOW_TYPE': 0.0,
#  'PLND_ENABLED': 0.0,
#  'RPM1_TYPE': 0.0,
#  'RPM2_TYPE': 0.0,
#  'ADSB_TYPE': 0.0,
#  'AVD_ENABLE': 0.0,
#  'NTF_LED_BRIGHT': 3.0,
#  'NTF_BUZZ_TYPES': 5.0,
#  'NTF_LED_OVERRIDE': 0.0,
#  'NTF_DISPLAY_TYPE': 0.0,
#  'NTF_BUZZ_PIN': -1.0,
#  'NTF_LED_TYPES': 123079.0,
#  'NTF_BUZZ_ON_LVL': 1.0,
#  'NTF_BUZZ_VOLUME': 100.0,
#  'NTF_LED_LEN': 1.0,
#  'THROW_MOT_START': 0.0,
#  'THROW_ALT_MIN': 0.0,
#  'THROW_ALT_MAX': 0.0,
#  'OSD_TYPE': 0.0,
#  'CC_TYPE': 0.0,
#  'WP_NAVALT_MIN': 0.0,
#  'BTN_ENABLE': 0.0,
#  'THROW_NEXTMODE': 18.0,
#  'THROW_TYPE': 0.0,
#  'GND_EFFECT_COMP': 1.0,
#  'DEV_OPTIONS': 0.0,
#  'BCN_TYPE': 0.0,
#  'PRX_IGN_GND': 0.0,
#  'PRX_LOG_RAW': 0.0,
#  'PRX_FILT': 0.25,
#  'PRX_ALT_MIN': 1.0,
#  'PRX1_TYPE': 0.0,
#  'PRX2_TYPE': 0.0,
#  'PRX3_TYPE': 0.0,
#  'ACRO_THR_MID': 0.0,
#  'FRAME_CLASS': 1.0,
#  'SERVO1_MIN': 1100.0,
#  'SERVO1_MAX': 1900.0,
#  'SERVO1_TRIM': 1500.0,
#  'SERVO1_REVERSED': 0.0,
#  'SERVO1_FUNCTION': 33.0,
#  'SERVO2_MIN': 1100.0,
#  'SERVO2_MAX': 1900.0,
#  'SERVO2_TRIM': 1500.0,
#  'SERVO2_REVERSED': 0.0,
#  'SERVO2_FUNCTION': 34.0,
#  'SERVO3_MIN': 1100.0,
#  'SERVO3_MAX': 1900.0,
#  'SERVO3_TRIM': 1500.0,
#  'SERVO3_REVERSED': 0.0,
#  'SERVO3_FUNCTION': 35.0,
#  'SERVO4_MIN': 1100.0,
#  'SERVO4_MAX': 1900.0,
#  'SERVO4_TRIM': 1500.0,
#  'SERVO4_REVERSED': 0.0,
#  'SERVO4_FUNCTION': 36.0,
#  'SERVO5_MIN': 1100.0,
#  'SERVO5_MAX': 1900.0,
#  'SERVO5_TRIM': 1500.0,
#  'SERVO5_REVERSED': 0.0,
#  'SERVO5_FUNCTION': 0.0,
#  'SERVO6_MIN': 1100.0,
#  'SERVO6_MAX': 1900.0,
#  'SERVO6_TRIM': 1500.0,
#  'SERVO6_REVERSED': 0.0,
#  'SERVO6_FUNCTION': 0.0,
#  'SERVO7_MIN': 1100.0,
#  'SERVO7_MAX': 1900.0,
#  'SERVO7_TRIM': 1500.0,
#  'SERVO7_REVERSED': 0.0,
#  'SERVO7_FUNCTION': 0.0,
#  'SERVO8_MIN': 1100.0,
#  'SERVO8_MAX': 1900.0,
#  'SERVO8_TRIM': 1500.0,
#  'SERVO8_REVERSED': 0.0,
#  ...}

# %%
# Out:
# 🔍 Checking for active sensor MAVLink messages...
# Waiting for sensor messages (5 seconds)...
# ✅ IMU (accelerometer + gyro): RAW_IMU
# ✅ Barometer: SCALED_PRESSURE
# ✅ GPS: GPS_RAW_INT
#
# 🔍 Checking for sensor-related parameters...
# ✅ IMU enabled: None
# ✅ Compass enabled: None
# ✅ GPS module type: None
# ✅ Second GPS module type: None
# ✅ RangeFinder 1 type: None
# ✅ Optical flow type: None
# ✅ Barometer enabled: None
# ✅ ADSB receiver enabled: None
# ✅ EKF Position XY source: None
# ✅ EKF Yaw source: None

# %% [markdown]
# # 2. Load the waypoint file

# %%
mission = MissionLoader(conn.target_system, conn.target_component)
mission_path = (root / "plan" / "missions" / "simple_mission.waypoints").resolve()
count = mission.load(str(mission_path)) # your QGC WPL 110 file
print(f"✅ Loaded {count} waypoints")
# Out:
# ✅ Loaded 4 waypoints

# %% [markdown]
# # 3. Read the mission

# %%
# Retrieve each mission item
for i in range(count):
    wp = mission.item(i)
    cmd_name = CmdNav(wp.command).name
    print(
        f"🧭 Mission[{i}] → cmd: {cmd_name}, "
        f"x: {wp.x}, y: {wp.y}, z: {wp.z}, current: {wp.current}"
    )
# Out:
# 🧭 Mission[0] → cmd: WAYPOINT, x: -35.3633245, y: 149.1652241, z: 0.0, current: 0
# 🧭 Mission[1] → cmd: TAKEOFF, x: -35.3633245, y: 149.1652241, z: 5.0, current: 0
# 🧭 Mission[2] → cmd: WAYPOINT, x: -35.3632795, y: 149.1652241, z: 5.0, current: 0
# 🧭 Mission[3] → cmd: LAND, x: -35.3632795, y: 149.1652241, z: 0.0, current: 0

# %% [markdown]
# # 3. Clear any existing mission

# %%
conn.mav.mission_clear_all_send(conn.target_system, conn.target_component)
while True:
    msg = conn.recv_match(type='STATUSTEXT',blocking=False)
    if msg and msg.text == 'ArduPilot Ready':
        print("🧹 Cleared previous mission")
        break

# %% [markdown]
# # 4. Send new mission count

# %%
conn.mav.mission_count_send(conn.target_system, conn.target_component, mission.count())
print(f"📤 Sending {mission.count()} mission items")
# Out:
# 📤 Sending 4 mission items

# %% [markdown]
# # 5. Send each item in response to MISSION_REQUEST

# %%
for i in range(mission.count()):
    msg = conn.recv_match(type='MISSION_REQUEST', blocking=True, timeout=5)
    if not msg or msg.seq != i:
        raise RuntimeError(f"❌ Unexpected mission request: {msg}")
    conn.mav.send(mission.wp(i))
    print(f"✅ Sent mission item {i}")
# Out:
# ✅ Sent mission item 0
# ✅ Sent mission item 1
# ✅ Sent mission item 2
# ✅ Sent mission item 3

# %% [markdown]
# # 6. Wait for final MISSION_ACK

# %%
ack = conn.recv_match(type='MISSION_ACK', blocking=True, timeout=5)
if ack and MissionResult(ack.type) == MissionResult.ACCEPTED:
    print("🎉 Mission upload successful!")
else:
    print(f"⚠️ Mission upload failed or timed out: {ack}")
# Out:
# 🎉 Mission upload successful!

# %% [markdown]
# ## Check the mission

# %%
# Create a mission protocol loader
wp = MissionLoader()


# Request list of mission items
conn.mav.mission_request_list_send(conn.target_system, conn.target_component)

# Wait for mission count
msg = conn.recv_match(type='MISSION_COUNT', blocking=True, timeout=5)
if msg:
    mission_count = msg.count
    print(f"📦 UAV has {mission_count} mission items")
    # Retrieve each mission item
    for i in range(mission_count):
        conn.mav.mission_request_send(conn.target_system, conn.target_component, i)
        item = conn.recv_match(type='MISSION_ITEM', blocking=True, timeout=5)
        if item:
            wp.set(item, i)
            print(
                f"🧭 Mission[{i}] → cmd: {CmdNav(item.command).name}, "
                f"x: {item.x}, y: {item.y}, z: {item.z}, current: {item.current}"
            )
else:
    print('No mission count received')
# Out:
# 📦 UAV has 4 mission items
# 🧭 Mission[0] → cmd: WAYPOINT, x: 0.0, y: 0.0, z: 0.0, current: 0
# 🧭 Mission[1] → cmd: TAKEOFF, x: -35.36332702636719, y: 149.16522216796875, z: 5.0, current: 0
# 🧭 Mission[2] → cmd: WAYPOINT, x: -35.36328125, y: 149.16522216796875, z: 5.0, current: 0
# 🧭 Mission[3] → cmd: LAND, x: -35.36328125, y: 149.16522216796875, z: 0.0, current: 0

# %% [markdown]
# # Arm the uav

# %%
plan_auto = Plan.arm(name="arm")
plan_auto.bind(conn,verbose=2)
while plan_auto.state != State.DONE:
    plan_auto.act()
# Out:
# Vehicle 1: ▶️ Plan Started: 📋 arm
# Vehicle 1: ▶️ Action Started: 🔧 PREARM
# Vehicle 1: ▶️ Step Started: Check disarmed
# Vehicle 1: ✅ Step Done: Check disarmed
# Vehicle 1: ▶️ Step Started: Check EKF status
# Vehicle 1: ✅ Step Done: Check EKF status
# Vehicle 1: ▶️ Step Started: Check GPS
# Vehicle 1: ✅ Step Done: Check GPS
# Vehicle 1: ▶️ Step Started: Check system
# Vehicle 1: ✅ Step Done: Check system
# Vehicle 1: ✅ Action Done: 🔧 PREARM
# Vehicle 1: ▶️ Action Started: ⚙️ MODE: GUIDED
# Vehicle 1: ▶️ Step Started: Switch to GUIDED
# Vehicle 1: ✅ Step Done: Switch to GUIDED
# Vehicle 1: ✅ Action Done: ⚙️ MODE: GUIDED
# Vehicle 1: ▶️ Action Started: 🔐 ARM
# Vehicle 1: ▶️ Step Started: arm
# Vehicle 1: ✅ Step Done: arm
# Vehicle 1: ✅ Action Done: 🔐 ARM
# Vehicle 1: ✅ Plan Done: 📋 arm

# %% [markdown]
# # Start mission

# %%
conn.mav.command_long_send(
        conn.target_system,
        conn.target_component,
        Cmd.MISSION_START,
        0,
        0,
        0,
        0,
        0,
        0,
        0,
        0,
    )

# %% [markdown]
# # Monitoring

# %%
#ask_msg(conn, verbose=2, msg_id=MsgID.GLOBAL_POSITION_INT, interval=100_000)

last_seq = mission.count() - 1
seq=0
while True:
    msg = conn.recv_match(blocking=True, timeout=1)

    if not msg:
        print("⏳ Waiting for mission update...")
        continue

    # ✅ Reached a waypoint
    if msg.get_type() == "MISSION_ITEM_REACHED":
        msg = cast(mavlink.MAVLink_mission_item_reached_message, msg)
        print(f"📌 Reached waypoint: {msg.seq}")
        seq+=1
        if msg.seq == last_seq:
            print("✅ Final waypoint reached")

    # ✅ UAV position
    # elif msg.get_type() == "GLOBAL_POSITION_INT":
    #     msg = cast(mavlink.MAVLink_global_position_int_message, msg)
    #     lat = msg.lat / 1e7
    #     lon = msg.lon / 1e7
    #     alt = msg.relative_alt / 1000.0
    #     print(f"📍 Position: lat={lat:.7f}, lon={lon:.7f}, alt={alt:.2f} m")
        
    # ✅ Look for end hints in text
    # elif msg.get_type() == "STATUSTEXT":
    #     msg = cast(mavlink.MAVLink_statustext_message, msg)
    #     text = msg.text.strip().lower()
    #     if "disarming" in text:
    #         stop_msg(conn, msg_id=MsgID.GLOBAL_POSITION_INT)
    #         print("🏁 Mission completed")
    #         break
# Out:
# ⏳ Waiting for mission update...
# ⏳ Waiting for mission update...
# ⏳ Waiting for mission update...
# 📌 Reached waypoint: 1
# ⏳ Waiting for mission update...
# ⏳ Waiting for mission update...
# 📌 Reached waypoint: 2
# ⏳ Waiting for mission update...
# ⏳ Waiting for mission update...
# ⏳ Waiting for mission update...
# ⏳ Waiting for mission update...
# ⏳ Waiting for mission update...
# ⏳ Waiting for mission update...
# ⏳ Waiting for mission update...
# ⏳ Waiting for mission update...
# ⏳ Waiting for mission update...
# ⏳ Waiting for mission update...
