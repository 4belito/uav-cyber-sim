# %%
import json
import csv

input_log = "sensor_1_GLOBAL_POSITION_INT.log"
output_csv = "output.csv"

rows = []

with open(input_log, "r") as f:
    for line in f:
        data = json.loads(line)

        row = {
            "sysid": data.get("sysid"),
            "sender": data.get("sender"),
            "time_received": data.get("time_received"),
            "time_logged": data.get("time_logged"),
        }

        # Flatten msg dictionary
        msg = data.get("msg", {})
        for k, v in msg.items():
            row[k] = v

        rows.append(row)

# Collect all possible fieldnames (safe for variable messages)
fieldnames = sorted({key for row in rows for key in row.keys()})

with open(output_csv, "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(rows)

print(f"Saved {len(rows)} rows to {output_csv}")
# Out:
# Saved 454 rows to output.csv

# %%
import pandas as pd

df = pd.read_csv(output_csv)
