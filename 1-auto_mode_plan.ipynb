# %% [markdown]
# ## Simple Mission
#
# This notebook serves to check the ardupilot installation

# %%
import os
import subprocess
import time
from typing import cast

import pymavlink.dialects.v20.ardupilotmega as mavlink
from pymavlink import mavutil

from config import ARDUPILOT_VEHICLE_PATH, LOGS_PATH, VEH_PARAMS_PATH
from helpers import clean
from mavlink.util import connection
from plan import State
from plan.planner import Plan

clean()

# %% [markdown]
# ## Launch Copter (ardupilot)

# %%
#This must agrre with first waypoint in mission.waypoint
spawn_str= '47.397742,8.545594,0,0' 

sim_vehicle_path = os.path.expanduser(ARDUPILOT_VEHICLE_PATH)
vehicle_cmd = (
    f"python3 {sim_vehicle_path} "
    f"-v ArduCopter "
    f"-I0 --sysid 1 "
    f"--no-rebuild "
    f"--use-dir={LOGS_PATH} "
    f"--add-param-file {VEH_PARAMS_PATH} "
    f"--no-mavproxy "
    f'--custom-location={spawn_str}'
)


# Open a new terminal and run the command
subprocess.Popen(["gnome-terminal","--title=planner","--", 
                  "bash", "-c", f"{vehicle_cmd}; exec bash"])
# Out:
# <Popen: returncode: None args: ['gnome-terminal', '--title=planner', '--', '...>

# %% [markdown]
# ## 1. Connect to the vehicle

# %%
time.sleep(1)
conn = connection("tcp:127.0.0.1:5760")
conn.wait_heartbeat() 
print("✅ Heartbeat received")
# Out:
# ✅ Heartbeat received

# %% [markdown]
# # Execute Plan

# %%
plan_auto = Plan.auto(mission_name="simple_mission")
plan_auto.bind(conn,verbose=2)
while plan_auto.state != State.DONE:
    plan_auto.act()
# Out:
# Vehicle 1: ▶️ Plan Started: 📋
# Vehicle 1: ▶️ Action Started: 📤🚁  UPLOAD_MISSION
# Vehicle 1: ▶️ Step Started: clear uav missions
# 🎉 Mission upload successful!
# Vehicle 1: ✅ Step Done: clear uav missions
# ✅ 4 waypoints read.
# 🧭 Mission[0] → cmd: WAYPOINT, x: 47.397742, y: 8.545594, z: 0.0, current: 0
# 🧭 Mission[1] → cmd: TAKEOFF, x: 47.397742, y: 8.545594, z: 10.0, current: 0
# 🧭 Mission[2] → cmd: WAYPOINT, x: 47.397787, y: 8.545594, z: 10.0, current: 0
# 🧭 Mission[3] → cmd: LAND, x: 47.397787, y: 8.545594, z: 0.0, current: 0
# ✅ Sent mission item 0
# ✅ Sent mission item 1
# ✅ Sent mission item 2
# ✅ Sent mission item 3
# Vehicle 1: ▶️ Step Started: load mission simple_mission
# 🎉 Mission upload successful!
# Vehicle 1: ✅ Step Done: load mission simple_mission
# Vehicle 1: ✅ Action Done: 📤🚁  UPLOAD_MISSION
# Vehicle 1: ▶️ Action Started: 🔧 PREARM
# Vehicle 1: ▶️ Step Started: Check disarmed
# Vehicle 1: ✅ Step Done: Check disarmed
# 📡 Requested message EKF_STATUS_REPORT at 1.00 Hz
# Vehicle 1: ▶️ Step Started: Check EKF status
# ⌛ Waiting for EKF to be ready... Pending: ATTITUDE, VELOCITY_HORIZ, POS_VERT_ABS, POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# ⌛ Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# Vehicle 1: ✅ Step Done: Check EKF status
# 📡 Requested message GPS_RAW_INT at 1.00 Hz
# Vehicle 1: ▶️ Step Started: Check GPS
# Vehicle 1: ✅ Step Done: Check GPS
# 📡 Requested message SYS_STATUS at 1.00 Hz
# Vehicle 1: ▶️ Step Started: Check system
# Vehicle 1: ✅ Step Done: Check system
# Vehicle 1: ✅ Action Done: 🔧 PREARM
# Vehicle 1: ▶️ Action Started: ⚙️ MODE: GUIDED
# Vehicle 1: ▶️ Step Started: Switch to GUIDED
# Vehicle 1: ✅ Step Done: Switch to GUIDED
# Vehicle 1: ✅ Action Done: ⚙️ MODE: GUIDED
# Vehicle 1: ▶️ Action Started: 🔐 ARM
# Vehicle 1: ▶️ Step Started: arm
# Vehicle 1: ✅ Step Done: arm
# Vehicle 1: ✅ Action Done: 🔐 ARM
# Vehicle 1: ▶️ Action Started: 🚀 START_MISSION
# Vehicle 1: ▶️ Step Started: start_mission
# 🚀 Mission has started
# Vehicle 1: ✅ Step Done: start_mission
# Vehicle 1: ✅ Action Done: 🚀 START_MISSION
# Vehicle 1: ✅ Plan Done: 📋

# %% [markdown]
# # Monitoring

# %%
conn.mav.request_data_stream_send(
    conn.target_system,
    conn.target_component,
    mavutil.mavlink.MAV_DATA_STREAM_POSITION,  # Stream ID
    4,     # Frequency in Hz
    1      # Start (1 to enable streaming)
)


last_seq = 4- 1

while True:
    msg = conn.recv_match(blocking=True, timeout=1)

    if not msg:
        print("⏳ Waiting for mission update...")
        continue

    # ✅ Reached a waypoint
    if msg.get_type() == "MISSION_ITEM_REACHED":
        msg = cast(mavlink.MAVLink_mission_item_reached_message, msg)
        print(f"📌 Reached waypoint: {msg.seq}")
        if msg.seq == last_seq:
            print("✅ Final waypoint reached")

    # ✅ UAV position
    elif msg.get_type() == "GLOBAL_POSITION_INT":
        msg = cast(mavlink.MAVLink_global_position_int_message, msg)
        lat = msg.lat / 1e7
        lon = msg.lon / 1e7
        alt = msg.relative_alt / 1000.0
        print(f"📍 Position: lat={lat:.7f}, lon={lon:.7f}, alt={alt:.2f} m")

    # ✅ Look for end hints in text
    elif msg.get_type() == "STATUSTEXT":
        msg = cast(mavlink.MAVLink_statustext_message, msg)
        text = msg.text.strip().lower()
        if "disarming" in text:
            print("🏁 Mission completed")
            break
# Out:
# 📍 Position: lat=47.3977420, lon=8.5455940, alt=0.00 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=0.00 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=0.00 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=0.00 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=0.00 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=0.00 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=0.00 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=0.00 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=0.00 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=0.02 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=0.07 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=0.17 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=0.44 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=0.72 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=1.05 m
# 📍 Position: lat=47.3977420, lon=8.5455939, alt=1.44 m
# 📍 Position: lat=47.3977420, lon=8.5455938, alt=1.89 m
# 📍 Position: lat=47.3977420, lon=8.5455938, alt=2.41 m
# 📍 Position: lat=47.3977420, lon=8.5455938, alt=2.99 m
# 📍 Position: lat=47.3977420, lon=8.5455938, alt=3.61 m
# 📍 Position: lat=47.3977420, lon=8.5455937, alt=4.25 m
# 📍 Position: lat=47.3977420, lon=8.5455937, alt=4.87 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=5.47 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=6.02 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=6.54 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=7.01 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=7.45 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=7.85 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=8.22 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=8.55 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=8.86 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=9.13 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=9.37 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=9.57 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=9.74 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=9.87 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=9.96 m
# 📌 Reached waypoint: 1
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=10.01 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=10.01 m
# 📍 Position: lat=47.3977421, lon=8.5455937, alt=10.00 m
# 📍 Position: lat=47.3977424, lon=8.5455937, alt=9.98 m
# 📍 Position: lat=47.3977430, lon=8.5455937, alt=9.97 m
# 📍 Position: lat=47.3977440, lon=8.5455937, alt=9.96 m
# 📍 Position: lat=47.3977455, lon=8.5455937, alt=9.96 m
# 📍 Position: lat=47.3977476, lon=8.5455937, alt=9.96 m
# 📍 Position: lat=47.3977502, lon=8.5455937, alt=9.97 m
# 📍 Position: lat=47.3977532, lon=8.5455937, alt=9.97 m
# 📍 Position: lat=47.3977564, lon=8.5455937, alt=9.98 m
# 📍 Position: lat=47.3977598, lon=8.5455938, alt=9.98 m
# 📍 Position: lat=47.3977633, lon=8.5455938, alt=9.98 m
# 📍 Position: lat=47.3977668, lon=8.5455939, alt=9.99 m
# 📍 Position: lat=47.3977702, lon=8.5455939, alt=9.99 m
# 📍 Position: lat=47.3977735, lon=8.5455940, alt=9.99 m
# 📍 Position: lat=47.3977766, lon=8.5455940, alt=9.99 m
# 📍 Position: lat=47.3977794, lon=8.5455941, alt=9.99 m
# 📍 Position: lat=47.3977818, lon=8.5455941, alt=9.99 m
# 📍 Position: lat=47.3977836, lon=8.5455941, alt=9.99 m
# 📍 Position: lat=47.3977848, lon=8.5455941, alt=9.99 m
# 📍 Position: lat=47.3977855, lon=8.5455940, alt=9.99 m
# 📍 Position: lat=47.3977859, lon=8.5455940, alt=10.00 m
# 📍 Position: lat=47.3977861, lon=8.5455940, alt=10.00 m
# 📍 Position: lat=47.3977861, lon=8.5455940, alt=10.00 m
# 📌 Reached waypoint: 2
# 📍 Position: lat=47.3977862, lon=8.5455939, alt=10.00 m
# 📍 Position: lat=47.3977862, lon=8.5455939, alt=10.00 m
# 📍 Position: lat=47.3977863, lon=8.5455939, alt=9.99 m
# 📍 Position: lat=47.3977863, lon=8.5455940, alt=9.99 m
# 📍 Position: lat=47.3977864, lon=8.5455940, alt=9.99 m
# 📍 Position: lat=47.3977864, lon=8.5455940, alt=9.97 m
# 📍 Position: lat=47.3977864, lon=8.5455941, alt=9.90 m
# 📍 Position: lat=47.3977863, lon=8.5455941, alt=9.79 m
# 📍 Position: lat=47.3977863, lon=8.5455941, alt=9.66 m
# 📍 Position: lat=47.3977863, lon=8.5455941, alt=9.52 m
# 📍 Position: lat=47.3977863, lon=8.5455942, alt=9.39 m
# 📍 Position: lat=47.3977862, lon=8.5455942, alt=9.26 m
# 📍 Position: lat=47.3977862, lon=8.5455942, alt=9.13 m
# 📍 Position: lat=47.3977861, lon=8.5455941, alt=9.00 m
# 📍 Position: lat=47.3977861, lon=8.5455941, alt=8.88 m
# 📍 Position: lat=47.3977860, lon=8.5455941, alt=8.75 m
# 📍 Position: lat=47.3977860, lon=8.5455941, alt=8.63 m
# 📍 Position: lat=47.3977860, lon=8.5455941, alt=8.51 m
# 📍 Position: lat=47.3977859, lon=8.5455941, alt=8.38 m
# 📍 Position: lat=47.3977859, lon=8.5455941, alt=8.26 m
# 📍 Position: lat=47.3977859, lon=8.5455941, alt=8.13 m
# 📍 Position: lat=47.3977859, lon=8.5455941, alt=8.01 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=7.88 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=7.76 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=7.63 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=7.51 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=7.38 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=7.26 m
# 📍 Position: lat=47.3977858, lon=8.5455940, alt=7.13 m
# 📍 Position: lat=47.3977858, lon=8.5455940, alt=7.01 m
# 📍 Position: lat=47.3977858, lon=8.5455940, alt=6.88 m
# 📍 Position: lat=47.3977858, lon=8.5455940, alt=6.76 m
# 📍 Position: lat=47.3977858, lon=8.5455940, alt=6.63 m
# 📍 Position: lat=47.3977858, lon=8.5455940, alt=6.51 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=6.38 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=6.26 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=6.13 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=6.01 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=5.88 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=5.76 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=5.63 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=5.51 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=5.38 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=5.26 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=5.13 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=5.01 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=4.88 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=4.76 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=4.63 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=4.51 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=4.38 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=4.26 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=4.13 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=4.01 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=3.88 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=3.76 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=3.63 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=3.51 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=3.38 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=3.26 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=3.13 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=3.01 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=2.88 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=2.76 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=2.63 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=2.51 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=2.38 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=2.26 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=2.13 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=2.01 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=1.89 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=1.76 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=1.64 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=1.51 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=1.39 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=1.26 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=1.14 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=1.01 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=0.89 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=0.76 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=0.64 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=0.51 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=0.39 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=0.26 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=0.14 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=0.01 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=-0.03 m
# 📍 Position: lat=47.3977858, lon=8.5455941, alt=-0.01 m
# 📍 Position: lat=47.3977857, lon=8.5455941, alt=-0.01 m
# 📍 Position: lat=47.3977857, lon=8.5455941, alt=-0.01 m
# 📍 Position: lat=47.3977857, lon=8.5455941, alt=-0.01 m
# 📍 Position: lat=47.3977857, lon=8.5455941, alt=-0.01 m
# 📍 Position: lat=47.3977857, lon=8.5455941, alt=-0.01 m
# 📍 Position: lat=47.3977857, lon=8.5455941, alt=-0.01 m
# 🏁 Mission completed
