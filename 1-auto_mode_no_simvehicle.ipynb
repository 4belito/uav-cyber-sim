# %% [markdown]
# ## Simple Mission in Auto-Mode
#
# This notebook serves to check the ardupilot installation and debugging

# %%
import time

from simulator.config import (
    ARDUCOPTER_BIN,
    ARDUPILOT_COPTER_PARAMS,
    DATA_PATH,
    LOGS_PATH,
    VEH_PARAMS_PATH,
    BasePort,
)
from simulator.helpers import (
    DataLogger,
    clean,
    create_process,
    setup_logging,
    terminate_process_group,
)
from simulator.helpers.connections import create_tcp_conn, wait_for_port
from simulator.helpers.coordinates import GRAPose
from simulator.planner import AutoPlan, Plan, State
from simulator.runtime import MAVLinkManager

clean()

# %% [markdown]
# ## Create auto plan

# %%
sysid = 1
speedup = 19
gra_origin = GRAPose(lat=-35.3633245,lon=149.1652241,alt=0,heading=0)

mission_path = "simulator/planner/missions/square_mission.waypoints"
plan = AutoPlan(name="basic_auto_plan", mission_path=mission_path)
plan
# Out:
# 🕓 <AutoPlan '📋 basic_auto_plan'>
#   🕓 <Action '💾 UPLOAD_MISSION'>
#     🕓 <ClearMission '🔹 clear previous mission'>
#     🕓 <UploadMission '🔹 upload mission'>
#   🕓 <Action '🛡️ PREARM'>
#     🕓 <CheckDisarmed '🔹 Check disarmed'>
#     🕓 <EKFStatus '🔹 Check EKF status'>
#     🕓 <GPSStatus '🔹 Check GPS'>
#     🕓 <CheckSystem '🔹 Check system status'>
#   🕓 <Action '⚙️ MODE'>
#     🕓 <SwitchMode '🔹 Switch to GUIDED'>
#   🕓 <Action '🔒 ARM'>
#     🕓 <Arm '🔹 arm'>
#   🕓 <Action '🚀 START_MISSION'>
#     🕓 <StartMission '🔹 start mission'>
#   🕓 <Action '👀 MONITOR_MISSION'>
#     🕓 <CheckItems '🔹 check items'>
#     🕓 <CheckEndMission '🔹 check end mission'>

# %% [markdown]
# ## Launch Copter (ardupilot)

# %%
spawn_str = gra_origin.to_str()

vehicle_cmd = [
    str(ARDUCOPTER_BIN),
    "-w",  # (optional but sim_vehicle uses it often)
    "--model", "quad",
    "--speedup", str(speedup),
    "--sysid", str(sysid),
    "--base-port", str(BasePort.ARP),
    "--sim-address", "127.0.0.1",
    "--home", spawn_str,
    "--serial5", f"uart:/tmp/adsb_{sysid}_ardupilot:57600",
    "--defaults", ",".join([
        str(ARDUPILOT_COPTER_PARAMS),
        str(VEH_PARAMS_PATH),
    ]),
]

veh_proc = create_process(
                " ".join(vehicle_cmd),
                after="exec bash",
                visible= False,
                suppress_output=True,
                title="ardu_vehicle",
                new_process_group=True,
            )
wait_for_port(port = BasePort.ARP, timeout = 0.5)

# %% [markdown]
# ## Connect to the vehicle

# %%
conn = create_tcp_conn(
    base_port=BasePort.ARP, 
    offset=0,
    role="client", 
    src_sysid=sysid,
    src_compid=140
)

print("✅ TCP connection established!")
# Out:
# ✅ TCP connection established!

# %% [markdown]
# # Save mission

# %%
enu_path = Plan.create_square_path(side_len=10, alt=5, clockwise=True)
gra_path=GRAPose.unpose_all(gra_origin.to_abs_all(enu_path))
plan.save_basic_mission(sysid=sysid,gra_wps=gra_path)

# %% [markdown]
# ## Start the Mavlink Mannager

# %%
data_logger = DataLogger(path=DATA_PATH / "msgs", sysid=sysid)
mav_mnng = MAVLinkManager(
    conn=conn,
    data_logger=data_logger
)
mav_mnng.start()

print("✅ MAVLink mannager started")
# Out:
# ✅ MAVLink mannager started

# %% [markdown]
# # Execute Auto Plan

# %%
setup_logging(LOGS_PATH/'plan',verbose=2)
plan.bind(gra_origin.unpose(), mav_mnng)
while plan.state != State.DONE:
    plan.act()
    time.sleep(0.1)
# Out:
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: ClearMission 'clear previous mission' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: UploadMission 'upload mission' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: Action 'UPLOAD_MISSION' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: Action 'UPLOAD_MISSION' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: CheckDisarmed 'Check disarmed' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: EKFStatus 'Check EKF status' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: GPSStatus 'Check GPS' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: CheckSystem 'Check system status' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: Action 'PREARM' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: Action 'PREARM' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: SwitchMode 'Switch to GUIDED' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: Action 'MODE' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: Action 'MODE' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: Arm 'arm' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: Action 'ARM' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: Action 'ARM' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: StartMission 'start mission' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: Action 'START_MISSION' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: Action 'START_MISSION' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: CheckItems 'check items' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: CheckEndMission 'check end mission' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: Action 'MONITOR_MISSION' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: Action 'MONITOR_MISSION' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: AutoPlan 'basic_auto_plan' is now connected
# 20:13:25 - plan - DEBUG - 🔗 Vehicle 1: AutoPlan 'basic_auto_plan' is now connected
# 20:13:25 - plan - DEBUG - ▶️ Vehicle 1: AutoPlan Started: 📋 basic_auto_plan
# 20:13:25 - plan - DEBUG - ▶️ Vehicle 1: Action Started: 💾 UPLOAD_MISSION
# 20:13:25 - plan - DEBUG - ▶️ Vehicle 1: ClearMission Started: clear previous mission
# 20:13:25 - plan - INFO - 🧹 Vehicle 1: Cleared previous mission
# 20:13:25 - plan - DEBUG - ✅ Vehicle 1: ClearMission Done: clear previous mission
# 20:13:26 - plan - INFO - ✅ Vehicle 1: 7 waypoints read
# 20:13:26 - plan - DEBUG - 🧭 Vehicle 1: Mission[0] → cmd: NAV_WAYPOINT, x: -35.363324, y: 149.165224, z: 0.0, current: 0
# 20:13:26 - plan - DEBUG - 🧭 Vehicle 1: Mission[1] → cmd: NAV_TAKEOFF, x: -35.363324, y: 149.165224, z: 5.0, current: 0
# 20:13:26 - plan - DEBUG - 🧭 Vehicle 1: Mission[2] → cmd: NAV_WAYPOINT, x: -35.363234, y: 149.165224, z: 5.000008, current: 0
# 20:13:26 - plan - DEBUG - 🧭 Vehicle 1: Mission[3] → cmd: NAV_WAYPOINT, x: -35.363234, y: 149.165334, z: 5.000016, current: 0
# 20:13:26 - plan - DEBUG - 🧭 Vehicle 1: Mission[4] → cmd: NAV_WAYPOINT, x: -35.363324, y: 149.165334, z: 5.000008, current: 0
# 20:13:26 - plan - DEBUG - 🧭 Vehicle 1: Mission[5] → cmd: NAV_WAYPOINT, x: -35.363324, y: 149.165224, z: 5.0, current: 0
# 20:13:26 - plan - DEBUG - 🧭 Vehicle 1: Mission[6] → cmd: NAV_LAND, x: -35.363324, y: 149.165224, z: 0.0, current: 0
# 20:13:26 - plan - DEBUG - ✅ Vehicle 1: Sent mission item 0
# 20:13:26 - plan - DEBUG - ✅ Vehicle 1: Sent mission item 1
# 20:13:26 - plan - DEBUG - ✅ Vehicle 1: Sent mission item 2
# 20:13:26 - plan - DEBUG - ✅ Vehicle 1: Sent mission item 3
# 20:13:26 - plan - DEBUG - ✅ Vehicle 1: Sent mission item 4
# 20:13:26 - plan - DEBUG - ✅ Vehicle 1: Sent mission item 5
# 20:13:26 - plan - DEBUG - ✅ Vehicle 1: Sent mission item 6
# 20:13:26 - plan - DEBUG - ▶️ Vehicle 1: UploadMission Started: upload mission
# 20:13:26 - plan - INFO - ✅ Vehicle 1: Mission upload successful!
# 20:13:26 - plan - DEBUG - ✅ Vehicle 1: UploadMission Done: upload mission
# 20:13:26 - plan - INFO - ✅ Vehicle 1: Action Done: 💾 UPLOAD_MISSION
# 20:13:26 - plan - DEBUG - ▶️ Vehicle 1: Action Started: 🛡️ PREARM
# 20:13:26 - plan - DEBUG - ▶️ Vehicle 1: CheckDisarmed Started: Check disarmed
# 20:13:26 - plan - DEBUG - ✅ Vehicle 1: CheckDisarmed Done: Check disarmed
# 20:13:27 - plan - DEBUG - ▶️ Vehicle 1: EKFStatus Started: Check EKF status
# 20:13:27 - plan - DEBUG - 🛰️ Vehicle 1: Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# 20:13:27 - plan - DEBUG - 🛰️ Vehicle 1: Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# 20:13:27 - plan - DEBUG - 🛰️ Vehicle 1: Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# 20:13:27 - plan - DEBUG - 🛰️ Vehicle 1: Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# 20:13:27 - plan - DEBUG - 🛰️ Vehicle 1: Waiting for EKF to be ready... Pending: POS_HORIZ_ABS
# 20:13:27 - plan - DEBUG - ✅ Vehicle 1: EKFStatus Done: Check EKF status
# 20:13:27 - plan - DEBUG - ▶️ Vehicle 1: GPSStatus Started: Check GPS
# 20:13:27 - plan - DEBUG - ✅ Vehicle 1: GPSStatus Done: Check GPS
# 20:13:28 - plan - DEBUG - ▶️ Vehicle 1: CheckSystem Started: Check system status
# 20:13:28 - plan - DEBUG - ✅ Vehicle 1: CheckSystem Done: Check system status
# 20:13:28 - plan - INFO - ✅ Vehicle 1: Action Done: 🛡️ PREARM
# 20:13:28 - plan - DEBUG - ▶️ Vehicle 1: Action Started: ⚙️ MODE
# 20:13:28 - plan - DEBUG - ▶️ Vehicle 1: SwitchMode Started: Switch to GUIDED
# 20:13:28 - plan - DEBUG - ✅ Vehicle 1: SwitchMode Done: Switch to GUIDED
# 20:13:28 - plan - INFO - ✅ Vehicle 1: Action Done: ⚙️ MODE
# 20:13:29 - plan - DEBUG - ▶️ Vehicle 1: Action Started: 🔒 ARM
# 20:13:29 - plan - DEBUG - ▶️ Vehicle 1: Arm Started: arm
# 20:13:29 - plan - DEBUG - ✅ Vehicle 1: Arm Done: arm
# 20:13:29 - plan - INFO - ✅ Vehicle 1: Action Done: 🔒 ARM
# 20:13:29 - plan - DEBUG - ▶️ Vehicle 1: Action Started: 🚀 START_MISSION
# 20:13:29 - plan - DEBUG - ▶️ Vehicle 1: StartMission Started: start mission
# 20:13:29 - plan - INFO - 🚀 Vehicle 1: Mission has started
# 20:13:29 - plan - DEBUG - ✅ Vehicle 1: StartMission Done: start mission
# 20:13:29 - plan - INFO - ✅ Vehicle 1: Action Done: 🚀 START_MISSION
# 20:13:30 - plan - DEBUG - ▶️ Vehicle 1: Action Started: 👀 MONITOR_MISSION
# 20:13:30 - plan - DEBUG - ▶️ Vehicle 1: CheckItems Started: check items
# 20:13:30 - plan - INFO - 📦 Vehicle 1 has 7 mission items
# 20:13:30 - plan - INFO - Vehicle 1: ⭐ Reached item: 0
# 20:13:30 - plan - INFO - Vehicle 1: ⭐ Reached item: 1
# 20:13:30 - plan - INFO - Vehicle 1: 📍 Target Position: ENU(x=-0.18, y=9.88, z=5.0)
# 20:13:30 - plan - INFO - Vehicle 1: ⭐ Reached item: 2
# 20:13:30 - plan - INFO - Vehicle 1: 📍 Target Position: ENU(x=9.53, y=9.88, z=5.0)
# 20:13:30 - plan - INFO - Vehicle 1: ⭐ Reached item: 3
# 20:13:30 - plan - INFO - Vehicle 1: 📍 Target Position: ENU(x=9.53, y=-0.28, z=5.0)
# 20:13:30 - plan - INFO - Vehicle 1: ⭐ Reached item: 4
# 20:13:30 - plan - INFO - Vehicle 1: 📍 Target Position: ENU(x=-0.18, y=-0.28, z=5.0)
# 20:13:30 - plan - INFO - Vehicle 1: ⭐ Reached item: 5
# 20:13:30 - plan - INFO - Vehicle 1: 📍 Target Position: ENU(x=-0.18, y=-0.28, z=-0.0)
# 20:13:30 - plan - DEBUG - ✅ Vehicle 1: CheckItems Done: check items
# 20:13:31 - plan - DEBUG - ▶️ Vehicle 1: CheckEndMission Started: check end mission
# 20:13:34 - plan - INFO - Vehicle 1: Mission completed
# 20:13:34 - plan - DEBUG - ✅ Vehicle 1: CheckEndMission Done: check end mission
# 20:13:34 - plan - INFO - ✅ Vehicle 1: Action Done: 👀 MONITOR_MISSION
# 20:13:34 - plan - INFO - ✅ Vehicle 1: AutoPlan Done: 📋 basic_auto_plan

# %% [markdown]
# ## Close connection and vehicle process

# %%
mav_mnng.stop()
terminate_process_group(veh_proc,"vehicle_process")
# Out:
# 20:13:34 - plan - DEBUG - process vehicle_process terminated

# %%
plan
# Out:
# ✅ <AutoPlan '📋 basic_auto_plan'>
#   ✅ <Action '💾 UPLOAD_MISSION'>
#     ✅ <ClearMission '🔹 clear previous mission'>
#     ✅ <UploadMission '🔹 upload mission'>
#   ✅ <Action '🛡️ PREARM'>
#     ✅ <CheckDisarmed '🔹 Check disarmed'>
#     ✅ <EKFStatus '🔹 Check EKF status'>
#     ✅ <GPSStatus '🔹 Check GPS'>
#     ✅ <CheckSystem '🔹 Check system status'>
#   ✅ <Action '⚙️ MODE'>
#     ✅ <SwitchMode '🔹 Switch to GUIDED'>
#   ✅ <Action '🔒 ARM'>
#     ✅ <Arm '🔹 arm'>
#   ✅ <Action '🚀 START_MISSION'>
#     ✅ <StartMission '🔹 start mission'>
#   ✅ <Action '👀 MONITOR_MISSION'>
#     ✅ <CheckItems '🔹 check items'>
#     ✅ <CheckEndMission '🔹 check end mission'>
